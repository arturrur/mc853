# %% [markdown]
# <a href="https://colab.research.google.com/github/arturrur/mc853/blob/main/Preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Ler arquivo csv e manter apenas as colunas necessárias

# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/arturrur/mc853/refs/heads/main/source/csv/LEPTBR23.csv", usecols=["SEM_NOT", "SG_UF_NOT", "DT_NOTIFIC" , "DT_SIN_PRI", "NU_IDADE_N",
                                                                                                                      "CS_SEXO", "CS_ESCOL_N", "CS_GESTANT", "NDUPLIC_N", "ANT_CB_LAM", "ANT_CB_CRI", "CS_RACA",
                                                                                                                      "ANT_CB_CAI", "ANT_CB_FOS", "ANT_CB_SIN", "ANT_CB_PLA", "ANT_CB_COR",
                                                                                                                      "ANT_CB_ROE", "ANT_CB_GRA", "ANT_CB_TER", "ANT_CB_LIX", 'CLI_FEBRE',
                                                                                                                      'CLI_MIALGI', 'CLI_CEFALE', 'CLI_PROST', 'CLI_CONGES', 'CLI_PANTUR',
                                                                                                                      'CLI_VOMITO', 'CLI_DIARRE', 'CLI_ICTERI','CLI_RENAL', 'CLI_RESPIR',
                                                                                                                      'CLI_CARDIA', 'CLI_HEMOPU', 'CLI_HEMORR', 'CLI_MENING', "ANT_HUMANO",
                                                                                                                      "ANT_ANIMAI", "CLI_DT_ATE", "EVOLUCAO"])
df["DT_NOTIFIC"] = pd.to_datetime(df["DT_NOTIFIC"])
df["DT_SIN_PRI"] = pd.to_datetime(df["DT_SIN_PRI"])
df["CLI_DT_ATE"] = pd.to_datetime(df["CLI_DT_ATE"])
df
# Out:
#       DT_NOTIFIC  SEM_NOT  SG_UF_NOT DT_SIN_PRI  NU_IDADE_N CS_SEXO  \
# 0     2023-01-01   202301         41 2022-12-29        4048       M
# 1     2023-01-01   202301         52 2022-12-15        4026       M
# 2     2023-01-01   202301         41 2022-12-31        4036       M
# 3     2023-01-01   202301         41 2022-12-30        4007       F
# 4     2023-01-01   202301         41 2023-01-01        4036       M
# ...          ...      ...        ...        ...         ...     ...
# 20229 2023-12-31   202401         43 2023-12-25        4035       M
# 20230 2023-12-31   202401         41 2023-12-30        4002       M
# 20231 2023-12-31   202401         41 2023-12-30        4027       M
# 20232 2023-12-31   202401         15 2023-12-28        4048       F
# 20233 2023-12-31   202401         43 2023-12-29        4019       F
#
#        CS_GESTANT  CS_RACA  CS_ESCOL_N  NDUPLIC_N  ...  CLI_VOMITO  \
# 0               6      1.0         2.0        NaN  ...         2.0
# ...

# %% [markdown]
# - Remover linhas do df que não tenham valor para a coluna "EVOLUCAO" ou que tenham valor ignorado

# %%
df = df.dropna(subset=["EVOLUCAO"])
df = df[df["EVOLUCAO"] != 9.0]
df
# Out:
#       DT_NOTIFIC  SEM_NOT  SG_UF_NOT DT_SIN_PRI  NU_IDADE_N CS_SEXO  \
# 3     2023-01-01   202301         41 2022-12-30        4007       F
# 4     2023-01-01   202301         41 2023-01-01        4036       M
# 6     2023-01-01   202301         35 2022-12-19        4025       M
# 7     2023-01-01   202301         33 2023-01-01        4029       M
# 8     2023-01-01   202301         31 2022-12-23        4012       M
# ...          ...      ...        ...        ...         ...     ...
# 20228 2023-12-31   202401         41 2023-12-29        4021       F
# 20229 2023-12-31   202401         43 2023-12-25        4035       M
# 20230 2023-12-31   202401         41 2023-12-30        4002       M
# 20231 2023-12-31   202401         41 2023-12-30        4027       M
# 20233 2023-12-31   202401         43 2023-12-29        4019       F
#
#        CS_GESTANT  CS_RACA  CS_ESCOL_N  NDUPLIC_N  ...  CLI_VOMITO  \
# 3               6      1.0         0.0        NaN  ...         1.0
# ...

# %% [markdown]
# - Remover duplicatas, por meio da coluna NDUPLIC_N
# - Remover a coluna NDUPLIC_N, que não tem mais uso

# %%
df = df[df["NDUPLIC_N"] != 2.0]
df = df.drop(columns=["NDUPLIC_N"])
df
# Out:
#       DT_NOTIFIC  SEM_NOT  SG_UF_NOT DT_SIN_PRI  NU_IDADE_N CS_SEXO  \
# 3     2023-01-01   202301         41 2022-12-30        4007       F
# 4     2023-01-01   202301         41 2023-01-01        4036       M
# 6     2023-01-01   202301         35 2022-12-19        4025       M
# 7     2023-01-01   202301         33 2023-01-01        4029       M
# 8     2023-01-01   202301         31 2022-12-23        4012       M
# ...          ...      ...        ...        ...         ...     ...
# 20228 2023-12-31   202401         41 2023-12-29        4021       F
# 20229 2023-12-31   202401         43 2023-12-25        4035       M
# 20230 2023-12-31   202401         41 2023-12-30        4002       M
# 20231 2023-12-31   202401         41 2023-12-30        4027       M
# 20233 2023-12-31   202401         43 2023-12-29        4019       F
#
#        CS_GESTANT  CS_RACA  CS_ESCOL_N  ANT_CB_LAM  ...  CLI_VOMITO  \
# 3               6      1.0         0.0         2.0  ...         1.0
# ...

# %% [markdown]
# Criar bitmap a partir da coluna SG_UF_NOT, depois deletar SG_UF_NOT

# %%
regions ={
    1: "Norte",
    2: "Nordeste",
    3: "Sudeste",
    4: "Sul",
    5: "Centro-Oeste"
}
df["int"] = df["SG_UF_NOT"] // 10
df["region"] = df["int"].map(regions)
df = pd.get_dummies(df, columns=['region'], prefix='', prefix_sep='')
df = df.drop(columns=["int", "SG_UF_NOT"])

print(df)
# Out:
#       DT_NOTIFIC  SEM_NOT DT_SIN_PRI  NU_IDADE_N CS_SEXO  CS_GESTANT  CS_RACA  \
# 3     2023-01-01   202301 2022-12-30        4007       F           6      1.0
# 4     2023-01-01   202301 2023-01-01        4036       M           6      1.0
# 6     2023-01-01   202301 2022-12-19        4025       M           6      4.0
# 7     2023-01-01   202301 2023-01-01        4029       M           6      9.0
# 8     2023-01-01   202301 2022-12-23        4012       M           6      4.0
# ...          ...      ...        ...         ...     ...         ...      ...
# 20228 2023-12-31   202401 2023-12-29        4021       F           5      1.0
# 20229 2023-12-31   202401 2023-12-25        4035       M           6      1.0
# 20230 2023-12-31   202401 2023-12-30        4002       M           6      1.0
# 20231 2023-12-31   202401 2023-12-30        4027       M           6      1.0
# 20233 2023-12-31   202401 2023-12-29        4019       F           5      4.0
#
# ...

# %% [markdown]
# Reformatar SEM_NOT, que está na forma aaaass, para apenas ss (semana). Também transformar a primeira semana do ano 2024 para a semana 53 do ano 2023. Obs: Teve uma amostra que tinha o valor de SEM_NOT como 2350, muito provavelmente um erro de digitação para 202350, ajustamos seu valor

# %%
df.loc[df['SEM_NOT'] == 202401, 'SEM_NOT'] = 202353
df.loc[df['SEM_NOT'] == 2350, 'SEM_NOT'] = 202350
df['SEM_NOT'] = df['SEM_NOT'] % 100
df
# Out:
#       DT_NOTIFIC  SEM_NOT DT_SIN_PRI  NU_IDADE_N CS_SEXO  CS_GESTANT  CS_RACA  \
# 3     2023-01-01        1 2022-12-30        4007       F           6      1.0
# 4     2023-01-01        1 2023-01-01        4036       M           6      1.0
# 6     2023-01-01        1 2022-12-19        4025       M           6      4.0
# 7     2023-01-01        1 2023-01-01        4029       M           6      9.0
# 8     2023-01-01        1 2022-12-23        4012       M           6      4.0
# ...          ...      ...        ...         ...     ...         ...      ...
# 20228 2023-12-31       53 2023-12-29        4021       F           5      1.0
# 20229 2023-12-31       53 2023-12-25        4035       M           6      1.0
# 20230 2023-12-31       53 2023-12-30        4002       M           6      1.0
# 20231 2023-12-31       53 2023-12-30        4027       M           6      1.0
# 20233 2023-12-31       53 2023-12-29        4019       F           5      4.0
#
# ...

# %% [markdown]
# Criar uma coluna que representa a quantidade de dias entre primeiros sintomas e data de atendimento. Tirar dos dados aqueles que têm mais de 20 dias entre as duas datas. Remover as colunas CLI_DT_ATE e DT_SIN_PRI, que não têm mais uso.

# %%
df['DIF_SINTOMAS_ATEND'] = (df['CLI_DT_ATE'] - df['DT_SIN_PRI']).dt.days
df = df[(df['DIF_SINTOMAS_ATEND'] <= 20) & (df['DIF_SINTOMAS_ATEND'] >= 0)]
df = df.drop(columns=["CLI_DT_ATE", "DT_SIN_PRI"])

df
# Out:
#       DT_NOTIFIC  SEM_NOT  NU_IDADE_N CS_SEXO  CS_GESTANT  CS_RACA  \
# 3     2023-01-01        1        4007       F           6      1.0
# 4     2023-01-01        1        4036       M           6      1.0
# 6     2023-01-01        1        4025       M           6      4.0
# 7     2023-01-01        1        4029       M           6      9.0
# 8     2023-01-01        1        4012       M           6      4.0
# ...          ...      ...         ...     ...         ...      ...
# 20228 2023-12-31       53        4021       F           5      1.0
# 20229 2023-12-31       53        4035       M           6      1.0
# 20230 2023-12-31       53        4002       M           6      1.0
# 20231 2023-12-31       53        4027       M           6      1.0
# 20233 2023-12-31       53        4019       F           5      4.0
#
#        CS_ESCOL_N  ANT_CB_LAM  ANT_CB_CRI  ANT_CB_CAI  ...  CLI_HEMOPU  \
# 3             0.0         2.0         2.0         2.0  ...         2.0
# ...

# %% [markdown]
# Transformar a coluna de gestante em uma booleana.
# - True se gestante
# - False caso contrário

# %%
df['CS_GESTANT'] = df['CS_GESTANT'].apply(lambda x: True if x in [1, 2, 3, 4] else False)
df
# Out:
#       DT_NOTIFIC  SEM_NOT  NU_IDADE_N CS_SEXO  CS_GESTANT  CS_RACA  \
# 3     2023-01-01        1        4007       F       False      1.0
# 4     2023-01-01        1        4036       M       False      1.0
# 6     2023-01-01        1        4025       M       False      4.0
# 7     2023-01-01        1        4029       M       False      9.0
# 8     2023-01-01        1        4012       M       False      4.0
# ...          ...      ...         ...     ...         ...      ...
# 20228 2023-12-31       53        4021       F       False      1.0
# 20229 2023-12-31       53        4035       M       False      1.0
# 20230 2023-12-31       53        4002       M       False      1.0
# 20231 2023-12-31       53        4027       M       False      1.0
# 20233 2023-12-31       53        4019       F       False      4.0
#
#        CS_ESCOL_N  ANT_CB_LAM  ANT_CB_CRI  ANT_CB_CAI  ...  CLI_HEMOPU  \
# 3             0.0         2.0         2.0         2.0  ...         2.0
# ...

# %% [markdown]
# - Remover todos que têm menos que 1 ano de idade
# - Reformatar a coluna de idade para mostrar apenas quantos anos eles têm

# %%
df = df[df['NU_IDADE_N'] // 1000 == 4]
df['NU_IDADE_N'] = df['NU_IDADE_N'] % 1000
df
# Out:
# <ipython-input-312-f7b7e6bf1fcd>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['NU_IDADE_N'] = df['NU_IDADE_N'] % 1000
#       DT_NOTIFIC  SEM_NOT  NU_IDADE_N CS_SEXO  CS_GESTANT  CS_RACA  \
# 3     2023-01-01        1           7       F       False      1.0
# 4     2023-01-01        1          36       M       False      1.0
# 6     2023-01-01        1          25       M       False      4.0
# 7     2023-01-01        1          29       M       False      9.0
# 8     2023-01-01        1          12       M       False      4.0
# ...          ...      ...         ...     ...         ...      ...
# 20228 2023-12-31       53          21       F       False      1.0
# ...

# %% [markdown]
# - Remover dados faltantes
# - Remover raças com poucos dados (amarela e indígena)
# - Criar um bitmap pras raças

# %%
racas = {
    1: "Branca",
    2: "Preta",
    3: "Amarela",
    4: "Parda",
    5: "Indígena",
    9: "Ignorado"
}

df = df.dropna(subset=["CS_RACA"])
df = df[df["CS_RACA"] != 9.0]
df = df[(df['CS_RACA'] != 3.0) & (df['CS_RACA'] != 5.0)] # a professora fez isso, não sei se devemos fazer tbm ou não
df["CS_RACA"] = df["CS_RACA"].map(racas)
df = pd.get_dummies(df, columns=['CS_RACA'], prefix='', prefix_sep='')
df
# Out:
#       DT_NOTIFIC  SEM_NOT  NU_IDADE_N CS_SEXO  CS_GESTANT  CS_ESCOL_N  \
# 3     2023-01-01        1           7       F       False         0.0
# 4     2023-01-01        1          36       M       False         9.0
# 6     2023-01-01        1          25       M       False         6.0
# 8     2023-01-01        1          12       M       False         9.0
# 10    2023-01-01        1          24       F       False         6.0
# ...          ...      ...         ...     ...         ...         ...
# 20228 2023-12-31       53          21       F       False         6.0
# 20229 2023-12-31       53          35       M       False         7.0
# 20230 2023-12-31       53           2       M       False        10.0
# 20231 2023-12-31       53          27       M       False         6.0
# 20233 2023-12-31       53          19       F       False         9.0
#
#        ANT_CB_LAM  ANT_CB_CRI  ANT_CB_CAI  ANT_CB_FOS  ...  EVOLUCAO  \
# ...

# %%
print(df[df['CS_ESCOL_N'].isna()].shape[0])
# Out:
# 878

# %%
print(df['NU_IDADE_N'].unique().tolist())
# Out:
# [7, 36, 25, 12, 24, 55, 59, 28, 26, 44, 23, 52, 35, 46, 5, 42, 63, 43, 47, 58, 64, 66, 38, 8, 17, 39, 57, 4, 31, 49, 54, 30, 32, 22, 67, 70, 34, 62, 41, 53, 56, 27, 51, 19, 45, 1, 71, 16, 48, 60, 68, 61, 18, 37, 6, 29, 50, 14, 33, 11, 65, 40, 82, 69, 21, 9, 10, 13, 2, 72, 20, 91, 15, 76, 74, 75, 79, 85, 3, 95, 78, 80, 73, 90, 77, 81, 93, 88, 87, 84, 89, 97, 86, 83, 92, 96, 106, 100]

# %%
print(df.groupby('CS_ESCOL_N').size())
# Out:
# CS_ESCOL_N
# 0.0      169
# 1.0      717
# 2.0      460
# 3.0     1187
# 4.0      796
# 5.0      901
# 6.0     2208
# 7.0      233
# 8.0      547
# 9.0     3385
# 10.0     446
# dtype: int64

# %%
print(df.groupby('CS_RACA').size())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-317-7dd1f27df4de> in <cell line: 0>()
# ----> 1 print(df.groupby('CS_RACA').size())
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9181             raise TypeError("You have to supply one of 'by' and 'level'")
#    9182
# -> 9183         return DataFrameGroupBy(
#    9184             obj=self,
#    9185             keys=by,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1327
#    1328         if grouper is None:
# -> 1329             grouper, exclusions, obj = get_grouper(
#    1330                 obj,
#    1331                 keys,
#
# ...

# %%
df_escol = df[df['CS_ESCOL_N'].isna()]
df_escol
